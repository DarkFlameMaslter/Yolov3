# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
import torch

# %%
cat_img = cv.imread("./data/meo.jpg")

plt.imshow(cv.cvtColor(cat_img, cv.COLOR_RGB2BGR))

# %%
m = torch.nn.Conv2d(3,,3,stride=3)

# %%
new_img_cat = m(cat_img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-44c5fb004adb> in <module>
# ----> 1 new_img_cat = m(cat_img)
#
# D:\TheEngineer\Anaconda\Anaconda\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# D:\TheEngineer\Anaconda\Anaconda\lib\site-packages\torch\nn\modules\conv.py in forward(self, input)
#     444
#     445     def forward(self, input: Tensor) -> Tensor:
# --> 446         return self._conv_forward(input, self.weight, self.bias)
# ...

# %%
inputs = torch.randn(1, 4, 5, 5)
print(inputs)
# Out:
# tensor([[[[ 0.4917, -0.3456,  1.4781, -0.9346, -0.4705],
#           [-0.8615,  0.3359,  1.2468,  0.4014,  0.7201],
#           [ 0.6984,  0.2784, -1.0725,  1.1410, -0.0536],
#           [ 0.0238,  1.3979,  1.6718, -0.3945,  1.0405],
#           [ 0.5928, -0.4525, -0.7904, -0.0168,  0.2902]],
#
#          [[ 0.9860,  1.6600,  1.6731, -0.3803,  0.3750],
#           [-0.6138,  1.1355, -2.6243,  0.6164, -1.5962],
#           [ 0.5535, -1.3772,  1.1217, -0.1927,  1.2005],
#           [-0.9793,  0.8749, -1.3347, -0.4300,  2.3722],
#           [ 0.5887, -0.2447,  0.2766, -0.4228, -0.2954]],
#
#          [[-0.0977,  0.8274,  0.2197, -0.3785,  1.2218],
#           [ 0.6891, -1.2009,  0.5790, -0.9333,  0.7933],
#           [-0.3572,  1.1386, -0.7442, -0.1677,  0.9180],
#           [-0.5203,  0.8854, -1.0220, -0.3192, -0.9629],
#           [-0.8770, -0.2135,  1.3742,  0.6108,  0.1036]],
#
#          [[-1.3594, -1.0127,  0.6177, -0.2060,  2.1485],
# ...

# %%
print(cat_img)
# Out:
# [[[25 13 63]
#   [23 11 59]
#   [22 12 59]
#   ...
#   [21 33 67]
#   [22 34 68]
#   [27 39 73]]
#
#  [[26 14 64]
#   [22 11 61]
#   [22 12 59]
#   ...
#   [18 30 64]
#   [17 29 63]
#   [22 34 68]]
#
#  [[28 17 67]
#   [25 14 64]
#   [23 15 62]
#   ...
#   [17 29 65]
#   [17 29 65]
#   [20 32 68]]
#
#  ...
#
#  [[35 29 52]
#   [34 28 51]
#   [31 25 48]
#   ...
#   [17 24 51]
#   [18 24 53]
#   [16 22 51]]
#
#  [[28 22 45]
#   [31 25 48]
#   [32 26 49]
#   ...
#   [13 20 47]
#   [13 19 48]
#   [11 17 46]]
#
#  [[28 22 45]
#   [32 26 49]
#   [33 27 50]
#   ...
#   [12 19 46]
#   [10 16 45]
#   [ 9 15 44]]]
